# %%
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)
import regex as re

# %%
asthma_df = pd.read_csv(r"C:\Users\ormis\Desktop\US chronic Asthma.csv")
asthma_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource   Topic  \
# 0       2016     2016           AR     Arkansas  SEDD; SID  Asthma
# 1       2017     2017           AZ      Arizona  SEDD; SID  Asthma
# 2       2016     2016           CA   California  SEDD; SID  Asthma
# 3       2015     2015           CO     Colorado  SEDD; SID  Asthma
# 4       2017     2017           CO     Colorado  SEDD; SID  Asthma
#
#                                      Question  Response DataValueUnit  \
# 0  Emergency department visit rate for asthma       NaN           NaN
# 1  Emergency department visit rate for asthma       NaN           NaN
# 2  Emergency department visit rate for asthma       NaN           NaN
# 3  Emergency department visit rate for asthma       NaN           NaN
# 4  Emergency department visit rate for asthma       NaN           NaN
#
#   DataValueType  ...  LocationID  TopicID QuestionID DataValueTypeID  \
# ...

# %%
asthma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80342 entries, 0 to 80341
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  80342 non-null  int64
#  1   YearEnd                    80342 non-null  int64
#  2   LocationAbbr               80342 non-null  object
#  3   LocationDesc               80342 non-null  object
#  4   DataSource                 80342 non-null  object
#  5   Topic                      80342 non-null  object
#  6   Question                   80342 non-null  object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              71930 non-null  object
#  9   DataValueType              80342 non-null  object
#  10  DataValue                  39846 non-null  float64
#  11  DataValueAlt               39846 non-null  float64
#  12  DataValueFootnoteSymbol    41684 non-null  object
# ...

# %%
asthma_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
data_2021 = asthma_df[(asthma_df['YearStart'] == 2021)]

# %%
#Extract only the rows where 'StratificationCategory1' is 'Gender'
flu_data = data_2021[data_2021['Question'] == 'Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma']
# Display the extracted gender data
print("\nInfluenza Vaccination Data:")
print(flu_data)
# Extract only the rows where 'StratificationCategory1' is 'Race/Ethnicity'
pneumo_data = data_2021[data_2021['Question'] == 'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma']
# Display the extracted ethnicity data
print("\nPneumococcal Vaccination Data:")
print(pneumo_data)

prevalence_data = data_2021[data_2021['Question'] == 'Current asthma prevalence among adults aged >= 18 years']
# Display the extracted ethnicity data
print("\nAsthma Prevalence Data:")
print(prevalence_data)

flu_data.head()

pneumo_data.head()

prevalence_data.head()
# Out:
# Influenza Vaccination Data:
#        YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 29076       2021     2021           DC  District of Columbia      BRFSS
# 29203       2021     2021           NH         New Hampshire      BRFSS
# 29359       2021     2021           UT                  Utah      BRFSS
# 29385       2021     2021           CO              Colorado      BRFSS
# 29413       2021     2021           AK                Alaska      BRFSS
# ...          ...      ...          ...                   ...        ...
# 79961       2021     2021           WY               Wyoming      BRFSS
# 80088       2021     2021           WY               Wyoming      BRFSS
# 80120       2021     2021           WY               Wyoming      BRFSS
# 80194       2021     2021           WY               Wyoming      BRFSS
# 80228       2021     2021           WY               Wyoming      BRFSS
#
#         Topic  \
# 29076  Asthma
# 29203  Asthma
# 29359  Asthma
# ...

# %%
asthma_flu_df = pd.DataFrame(flu_data)

asthma_pneumo_df = pd.DataFrame(pneumo_data)

asthma_prevalence_df = pd.DataFrame(prevalence_data)

# %%
# Code out as necessary

# asthma_flu_df

# asthma_pneumo_df

# asthma_prevalence_df
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc DataSource   Topic  \
# 170         2021     2021           OH         Ohio      BRFSS  Asthma
# 171         2021     2021           OH         Ohio      BRFSS  Asthma
# 28943       2021     2021           OK     Oklahoma      BRFSS  Asthma
# 28968       2021     2021           NE     Nebraska      BRFSS  Asthma
# 28974       2021     2021           NE     Nebraska      BRFSS  Asthma
# ...          ...      ...          ...          ...        ...     ...
# 79923       2021     2021           WY      Wyoming      BRFSS  Asthma
# 79965       2021     2021           WY      Wyoming      BRFSS  Asthma
# 80068       2021     2021           WY      Wyoming      BRFSS  Asthma
# 80136       2021     2021           WY      Wyoming      BRFSS  Asthma
# 80188       2021     2021           WY      Wyoming      BRFSS  Asthma
#
#                                                       Question  Response  \
# ...

# %%
asthma_flu_df.to_csv(r"C:\Users\ormis\Desktop\project_3\Resources\Flu.csv", index=False)

asthma_pneumo_df.to_csv(r"C:\Users\ormis\Desktop\project_3\Resources\Pneumo.csv", index=False)

asthma_prevalence_df.to_csv(r"C:\Users\ormis\Desktop\project_3\Resources\Prevalence.csv", index=False)

# %%
#Extract only the rows where 'StratificationCategory1' is 'Gender'
gender_data = data_2021[data_2021['StratificationCategory1'] == 'Gender']
# Display the extracted gender data
print("\nGender Data:")
print(gender_data)
# Extract only the rows where 'StratificationCategory1' is 'Race/Ethnicity'
ethnicity_data = data_2021[data_2021['StratificationCategory1'] == 'Race/Ethnicity']
# Display the extracted ethnicity data
print("\nRace/Ethnicity Data:")
print(ethnicity_data)

gender_data.head()

ethnicity_data.head()
# Out:
# Gender Data:
#        YearStart  YearEnd LocationAbbr  LocationDesc DataSource   Topic  \
# 28958       2021     2021           OR        Oregon      BRFSS  Asthma
# 28983       2021     2021           PA  Pennsylvania      BRFSS  Asthma
# 28988       2021     2021           NE      Nebraska      BRFSS  Asthma
# 29029       2021     2021           AR      Arkansas      BRFSS  Asthma
# 29042       2021     2021           AZ       Arizona      BRFSS  Asthma
# ...          ...      ...          ...           ...        ...     ...
# 80038       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80088       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80093       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80188       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80243       2021     2021           WY       Wyoming      BRFSS  Asthma
#
# ...

# %%
asthma_gender_df = pd.DataFrame(gender_data)

asthma_race_df = pd.DataFrame(ethnicity_data)

# %%
asthma_gender_df
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc DataSource   Topic  \
# 28958       2021     2021           OR        Oregon      BRFSS  Asthma
# 28983       2021     2021           PA  Pennsylvania      BRFSS  Asthma
# 28988       2021     2021           NE      Nebraska      BRFSS  Asthma
# 29029       2021     2021           AR      Arkansas      BRFSS  Asthma
# 29042       2021     2021           AZ       Arizona      BRFSS  Asthma
# ...          ...      ...          ...           ...        ...     ...
# 80038       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80088       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80093       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80188       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80243       2021     2021           WY       Wyoming      BRFSS  Asthma
#
#                                                                                       Question  \
# ...

# %%
asthma_race_df
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc DataSource   Topic  \
# 170         2021     2021           OH          Ohio      BRFSS  Asthma
# 28943       2021     2021           OK      Oklahoma      BRFSS  Asthma
# 28968       2021     2021           NE      Nebraska      BRFSS  Asthma
# 28982       2021     2021           PA  Pennsylvania      BRFSS  Asthma
# 28985       2021     2021           NE      Nebraska      BRFSS  Asthma
# ...          ...      ...          ...           ...        ...     ...
# 80143       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80169       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80190       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80194       2021     2021           WY       Wyoming      BRFSS  Asthma
# 80222       2021     2021           WY       Wyoming      BRFSS  Asthma
#
#                                                                                       Question  \
# ...

# %%
asthma_race_df.to_csv(r"C:\Users\ormis\Desktop\project_3\Resources\Race.csv", index=False)

asthma_gender_df.to_csv(r"C:\Users\ormis\Desktop\project_3\Resources\Gender.csv", index=False)

# %%
overall_data = data_2021[data_2021['StratificationCategory1'] == 'Overall']
# Display the extracted ethnicity data
print("\nOverall Data:")
print(overall_data)
# Out:
# Overall Data:
#        YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 171         2021     2021           OH                  Ohio      BRFSS
# 28974       2021     2021           NE              Nebraska      BRFSS
# 29005       2021     2021           ND          North Dakota      BRFSS
# 29043       2021     2021           AZ               Arizona      BRFSS
# 29076       2021     2021           DC  District of Columbia      BRFSS
# ...          ...      ...          ...                   ...        ...
# 80020       2021     2021           WY               Wyoming      BRFSS
# 80220       2021     2021           WY               Wyoming      BRFSS
# 80227       2021     2021           WY               Wyoming      BRFSS
# 80228       2021     2021           WY               Wyoming      BRFSS
# 80255       2021     2021           WY               Wyoming      BRFSS
#
#         Topic  \
# 171    Asthma
# 28974  Asthma
# 29005  Asthma
# 29043  Asthma
# ...

# %%
asthma_overall_df = pd.DataFrame(overall_data)

# %%
asthma_overall_df
# Out:
#        YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 171         2021     2021           OH                  Ohio      BRFSS
# 28974       2021     2021           NE              Nebraska      BRFSS
# 29005       2021     2021           ND          North Dakota      BRFSS
# 29043       2021     2021           AZ               Arizona      BRFSS
# 29076       2021     2021           DC  District of Columbia      BRFSS
# ...          ...      ...          ...                   ...        ...
# 80020       2021     2021           WY               Wyoming      BRFSS
# 80220       2021     2021           WY               Wyoming      BRFSS
# 80227       2021     2021           WY               Wyoming      BRFSS
# 80228       2021     2021           WY               Wyoming      BRFSS
# 80255       2021     2021           WY               Wyoming      BRFSS
#
#         Topic  \
# 171    Asthma
# 28974  Asthma
# 29005  Asthma
# 29043  Asthma
# 29076  Asthma
# ...

# %%
asthma_overall_df.to_csv(r"C:\Users\ormis\Desktop\project_3\Resources\Overall.csv", index=False)
